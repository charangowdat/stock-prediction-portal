# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
          # Create a figure containing a single Axes.
# plt.plot([1, 1, 2, 1, 1, 2], [1, 3, 3, 3, 2, 2])  # Plot some data on the Axes.
# plt.plot([3, 3, 4, 4], [3,1,1, 3])
# plt.plot([6, 5, 5, 6], [3,3, 1, 1])
# plt.plot([7, 7, 7, 8, 7, 8], [3, 1, 2, 3, 2, 1])
# plt.title('Fuck Plot')
# Out:
# Text(0.5, 1.0, 'Fuck Plot')

# %% [markdown]
# ## Line plot

# %%
x = [1, 2, 3, 4,5,6]
y=[1,3,4,3,5, 6]
plt.plot(x, y)
plt.xlabel('x-label')
plt.ylabel('y-label')
# Out:
# Text(0, 0.5, 'y-label')

# %% [markdown]
# ## Bar chart

# %%
months = ['Jan','Apr','Aug','Dec']
revenue = [1222,1432,1333,1622]

# %%
plt.bar(months, revenue)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Histogram

# %%
marks50 = np.random.randint(0,100,50)
marks50
# Out:
# array([65, 88, 15, 44, 33, 85, 74,  5, 73, 34,  8, 50, 20, 52, 73,  0, 15,
#        58, 12,  7, 53, 24, 22, 26, 57, 91, 42,  7, 59, 45, 72, 67, 51, 92,
#        56, 45, 57, 71, 52, 60, 46, 73, 35, 42, 50,  8, 86, 36, 76, 30])

# %%
plt.hist(marks50)
plt.title('marks')
plt.xlabel('marks')
plt.ylabel('No. of tudents')
# Out:
# Text(0, 0.5, 'No. of tudents')

# %%
plt.hist(marks50, bins=3)
plt.title('marks')
plt.xlabel('marks')
plt.ylabel('No. of tudents')
# Out:
# Text(0, 0.5, 'No. of tudents')

# %% [markdown]
# ### Scatter Plots

# %%
height = np.sort(np.random.randint(55, 100, 50))
weight = np.sort(np.random.randint(120, 200, 50))

# %%
plt.scatter(height, weight)
plt.title('Height vs weight')
plt.xlabel('Height in inches')
plt.ylabel('Weight in pounds')
# Out:
# Text(0, 0.5, 'Weight in pounds')

# %% [markdown]
# ### Subplots and legends

# %%
days = [1,2,3,4,5]
original_price = [10, 20,25,30,37]
predicted_price = [8,21,23,31,39]

# %%
plt.plot(days, original_price, 'b-o',label='Price')
plt.plot(days, predicted_price, 'r-o', label='Prediction')
plt.legend()
plt.title('Plot with Legends')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.savefig('eample_prediction.png', dpi=100) #Save the image

# %% [markdown]
# ### Subplots

# %%
#First subplot Original Price
plt.subplot(3, 1, 1)
plt.plot(days, original_price, 'b-o', label='Original Price')
plt.title('Original prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

#Second subplot Predicted Price
plt.subplot(3, 1, 2)
plt.plot(days, predicted_price, 'r-o', label='Predicted Price')
plt.title('Predicted prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

#Third subplot Difference between Original & Predicted Prices
price_difference = [o-p for o, p in zip(original_price, predicted_price)]
plt.subplot(3, 1, 3)
plt.bar(days, price_difference, color='purple', label='Price Difference')
plt.title('Difference between Original & Predicted Prices')
plt.xlabel('Days')
plt.ylabel('Price Difference')
plt.legend()
plt.tight_layout()

# %% [markdown]
# ### Plots using pandas DataFrame

# %%
df = pd.read_csv('auto_sales_data.csv')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
plt.bar(df['PRODUCTLINE'], df['SALES'])
plt.xticks(rotation=45, ha='center')
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Motorcycles'),
#   Text(1, 0, 'Classic Cars'),
#   Text(2, 0, 'Trucks and Buses'),
#   Text(3, 0, 'Vintage Cars'),
#   Text(4, 0, 'Planes'),
#   Text(5, 0, 'Ships'),
#   Text(6, 0, 'Trains')])

# %%
df = pd.read_csv('TSLA.csv')
df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
plt.plot(df.Close)
